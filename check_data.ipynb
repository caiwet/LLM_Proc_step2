# %%
import pandas as pd

# %%
df = pd.read_parquet('step2_gemini_output/final.parquet')
df
# Out:
#                                   patient_id  batch_id  \
# 0       0000b99e-2357-95d7-2086-da66aaa3bc8c         0
# 1       0000b99e-2357-95d7-2086-da66aaa3bc8c         1
# 2       0000f59a-d0b6-8386-1109-36c732cb7949         2
# 3       000129ea-7c51-8f65-b604-cb9931abc47a         3
# 4       000129ea-7c51-8f65-b604-cb9931abc47a         4
# ...                                      ...       ...
# 426755  ffffdb50-1640-f9d2-7f7d-100c463a5258    426755
# 426756  ffffdb50-1640-f9d2-7f7d-100c463a5258    426756
# 426757  ffffdb50-1640-f9d2-7f7d-100c463a5258    426757
# 426758  ffffdb50-1640-f9d2-7f7d-100c463a5258    426758
# 426759  ffffdb50-1640-f9d2-7f7d-100c463a5258    426759
#
#                                                    prompt  \
# 0       AbbreviationDictionary: {"tka": ["total knee a...
# 1       AbbreviationDictionary: {"koos": ["knee injury...
# 2       AbbreviationDictionary: {"care": ["consultatio...
# 3       AbbreviationDictionary: {"ldl": ["low density ...
# ...
